# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %%
import requests
from bs4 import BeautifulSoup

def check_url(url):
    try:
        # Send a request to the URL
        response = requests.get(url)

        # Check if the response is successful (HTTP status code within 200-299)
        if response.status_code >= 200 and response.status_code < 300:
            print(f"The URL {url} is working.")

            # If the response is successful, parse the page and find hyperlinks
            soup = BeautifulSoup(response.content, 'html.parser')
            links = soup.find_all('a', href=True)

            print("Hyperlinks on the page:")
            for link in links:
                print(link['href'])

        else:
            print(f"The URL {url} returned an error: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"An error occurred while checking the URL {url}: {e}")

def check_multiple_urls(urls):
    for url in urls:
        check_url(url)
        print()

# URLs to check
urls_to_check = [
    "https://www.w3schools.com/sql/",
    "https://yournewsreporter.com/advantages-of-buying-authentic-basketball-jerseys/",
    "https://yournewsreporter.com/4-tips-for-selecting-the-best-real-estate-agent/",
]

# Call the function to check the URLs
check_multiple_urls(urls_to_check)
# Out:
# The URL https://www.w3schools.com/sql/ is working.
# Hyperlinks on the page:
# https://www.w3schools.com
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0);
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# /signup/index.php
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# https://my-learning.w3schools.com
# https://campus.w3schools.com/collections/course-catalog
# /spaces/index.php
# https://billing.w3schools.com/products/spaces?frequency=monthly&changePlan=true
# https://spaces.w3schools.com/space/
# https://my-learning.w3schools.com
# /spaces/index.php
# https://campus.w3schools.com/collections/certifications
# https://billing.w3schools.com/products/spaces?frequency=monthly&changePlan=true
# https://profile.w3schools.com/logout
# https://www.facebook.com/w3schoolscom/
# https://www.instagram.com/w3schools.com_official/
# https://discord.gg/6Z7UaRbUQM
# https://www.linkedin.com/company/w3schools.com/
# /html/default.asp
# /html/default.asp
# /tags/default.asp
# /css/default.asp
# /css/default.asp
# /cssref/default.asp
# /css/css_rwd_intro.asp
# /css/css_rwd_intro.asp
# /bootstrap/bootstrap_ver.asp
# /bootstrap/bootstrap_ver.asp
# /w3css/default.asp
# /w3css/default.asp
# /w3css/w3css_references.asp
# /sass/default.php
# /sass/default.php
# /sass/sass_functions_string.php
# /colors/default.asp
# /colors/default.asp
# /colors/colors_fs595.asp
# /icons/default.asp
# /icons/default.asp
# /icons/icons_reference.asp
# /graphics/svg_intro.asp
# /graphics/svg_intro.asp
# /graphics/svg_reference.asp
# /graphics/canvas_intro.asp
# /graphics/canvas_intro.asp
# /graphics/canvas_reference.asp
# /graphics/default.asp
# /graphics/default.asp
# /charsets/default.asp
# /charsets/default.asp
# /howto/default.asp
# /howto/default.asp
# /ai/default.asp
# /ai/default.asp
# /gen_ai/index.php
# /gen_ai/index.php
# /gen_ai/chatgpt-3-5/index.php
# /gen_ai/chatgpt-3-5/index.php
# /gen_ai/chatgpt-4/index.php
# /gen_ai/chatgpt-4/index.php
# /gen_ai/bard/index.php
# /gen_ai/bard/index.php
# /python/python_ml_getting_started.asp
# /python/python_ml_getting_started.asp
# /datascience/default.asp
# /datascience/default.asp
# /python/numpy/default.asp
# /python/numpy/default.asp
# /python/pandas/default.asp
# /python/pandas/default.asp
# /python/scipy/index.php
# /python/scipy/index.php
# /python/matplotlib_intro.asp
# /python/matplotlib_intro.asp
# /statistics/index.php
# /statistics/index.php
# /excel/index.php
# /excel/index.php
# /googlesheets/index.php
# /googlesheets/index.php
# /spaces/index.php
# /spaces/index.php
# /where_to_start.asp
# /w3css/w3css_templates.asp
# /browsers/default.asp
# https://campus.w3schools.com
# /whatis/default.asp
# /tryit/default.asp
# /typingspeed/default.asp
# /codegame/index.html
# /cybersecurity/index.php
# /accessibility/index.php
# https://campus.w3schools.com/pages/newsletter
# /js/default.asp
# /js/default.asp
# /jsref/default.asp
# /react/default.asp
# /react/default.asp
# /jquery/default.asp
# /jquery/default.asp
# /jquery/jquery_ref_overview.asp
# /vue/index.php
# /vue/index.php
# /vue/vue_ref_builtin-attributes.php
# /angular/default.asp
# /angular/default.asp
# /angular/angular_ref_directives.asp
# /js/js_json_intro.asp
# /js/js_json_intro.asp
# /jsref/jsref_obj_json.asp
# /js/js_ajax_intro.asp
# /js/js_ajax_intro.asp
# /appml/default.asp
# /appml/default.asp
# /appml/appml_reference.asp
# /w3js/default.asp
# /w3js/default.asp
# /w3js/w3js_references.asp
# /spaces/index.php
# /spaces/index.php
# /where_to_start.asp
# /w3css/w3css_templates.asp
# /browsers/default.asp
# https://campus.w3schools.com
# /whatis/default.asp
# /tryit/default.asp
# /typingspeed/default.asp
# /codegame/index.html
# /cybersecurity/index.php
# /accessibility/index.php
# https://campus.w3schools.com/pages/newsletter
# /python/default.asp
# /python/default.asp
# /python/python_reference.asp
# /sql/default.asp
# /sql/default.asp
# /sql/sql_ref_keywords.asp
# /mysql/default.asp
# /mysql/default.asp
# /mysql/mysql_datatypes.asp
# /php/default.asp
# /php/default.asp
# /php/php_ref_overview.asp
# /java/default.asp
# /java/default.asp
# /java/java_ref_keywords.asp
# /c/index.php
# /c/index.php
# /cpp/default.asp
# /cpp/default.asp
# /cs/index.php
# /cs/index.php
# /r/default.asp
# /r/default.asp
# /kotlin/index.php
# /kotlin/index.php
# /go/index.php
# /go/index.php
# /django/index.php
# /django/index.php
# /django/django_ref_template_tags.php
# /postgresql/index.php
# /postgresql/index.php
# /typescript/index.php
# /typescript/index.php
# /asp/default.asp
# /asp/default.asp
# /asp/asp_ref_vbscript_functions.asp
# /nodejs/default.asp
# /nodejs/default.asp
# /nodejs/ref_modules.asp
# /nodejs/nodejs_raspberrypi.asp
# /nodejs/nodejs_raspberrypi.asp
# /git/default.asp
# /git/default.asp
# /mongodb/index.php
# /mongodb/index.php
# /aws/index.php
# /aws/index.php
# /xml/default.asp
# /xml/default.asp
# /xml/dom_nodetype.asp
# /ai/default.asp
# /ai/default.asp
# /gen_ai/index.php
# /gen_ai/index.php
# /gen_ai/chatgpt-3-5/index.php
# /gen_ai/chatgpt-3-5/index.php
# /gen_ai/chatgpt-4/index.php
# /gen_ai/chatgpt-4/index.php
# /gen_ai/bard/index.php
# /gen_ai/bard/index.php
# /python/python_ml_getting_started.asp
# /python/python_ml_getting_started.asp
# /datascience/default.asp
# /datascience/default.asp
# /python/numpy/default.asp
# /python/numpy/default.asp
# /python/pandas/default.asp
# /python/pandas/default.asp
# /python/scipy/index.php
# /python/scipy/index.php
# /python/matplotlib_intro.asp
# /python/matplotlib_intro.asp
# /statistics/index.php
# /statistics/index.php
# /excel/index.php
# /excel/index.php
# /googlesheets/index.php
# /googlesheets/index.php
# /spaces/index.php
# /spaces/index.php
# /where_to_start.asp
# /w3css/w3css_templates.asp
# /browsers/default.asp
# https://campus.w3schools.com
# /whatis/default.asp
# /tryit/default.asp
# /typingspeed/default.asp
# /codegame/index.html
# /cybersecurity/index.php
# /accessibility/index.php
# https://campus.w3schools.com/pages/newsletter
# /html/html_exercises.asp
# /html/html_exercises.asp
# /html/html_quiz.asp
# /css/css_exercises.asp
# /css/css_exercises.asp
# /css/css_quiz.asp
# /bootstrap/bootstrap_exercises.asp
# /bootstrap/bootstrap_exercises.asp
# /bootstrap/bootstrap_quiz.asp
# /python/numpy/numpy_exercises.asp
# /python/numpy/numpy_exercises.asp
# /python/numpy/numpy_quiz.asp
# /python/pandas/pandas_exercises.asp
# /python/pandas/pandas_exercises.asp
# /python/pandas/pandas_quiz.asp
# /python/scipy/scipy_exercises.php
# /python/scipy/scipy_exercises.php
# /python/scipy/scipy_quiz.php
# /excel/excel_exercises.php
# /excel/excel_exercises.php
# /exercises/index.php
# /quiztest/default.asp
# /js/js_exercises.asp
# /js/js_exercises.asp
# /js/js_quiz.asp
# /react/react_exercises.asp
# /react/react_exercises.asp
# /react/react_quiz.asp
# /jquery/jquery_exercises.asp
# /jquery/jquery_exercises.asp
# /jquery/jquery_quiz.asp
# /vue/vue_exercises.php
# /vue/vue_exercises.php
# /vue/vue_quiz.php
# /python/python_exercises.asp
# /python/python_exercises.asp
# /python/python_quiz.asp
# /sql/sql_exercises.asp
# /sql/sql_exercises.asp
# /sql/sql_quiz.asp
# /mysql/mysql_exercises.asp
# /mysql/mysql_exercises.asp
# /mysql/mysql_quiz.asp
# /php/php_exercises.asp
# /php/php_exercises.asp
# /php/php_quiz.asp
# /java/java_exercises.asp
# /java/java_exercises.asp
# /java/java_quiz.asp
# /c/c_exercises.php
# /c/c_exercises.php
# /c/c_quiz.php
# /cpp/cpp_exercises.asp
# /cpp/cpp_exercises.asp
# /cpp/cpp_quiz.asp
# /cs/cs_exercises.php
# /cs/cs_exercises.php
# /cs/cs_quiz.php
# /r/r_exercises.asp
# /r/r_exercises.asp
# /r/r_quiz.asp
# /kotlin/kotlin_exercises.php
# /kotlin/kotlin_exercises.php
# /kotlin/kotlin_quiz.php
# /django/django_exercises.php
# /django/django_exercises.php
# /django/django_quiz.php
# /postgresql/postgresql_exercises.php
# /postgresql/postgresql_exercises.php
# /postgresql/postgresql_quiz.php
# /typescript/typescript_exercises.php
# /typescript/typescript_exercises.php
# /typescript/typescript_quiz.php
# /git/git_exercises.asp
# /git/git_exercises.asp
# /git/git_quiz.asp
# /go/go_exercises.php
# /go/go_exercises.php
# /mongodb/mongodb_exercises.php
# /mongodb/mongodb_exercises.php
# /aws/aws_exercises.php
# /aws/aws_exercises.php
# /aws/aws_quiz.php
# /python/numpy/numpy_exercises.asp
# /python/numpy/numpy_exercises.asp
# /python/numpy/numpy_quiz.asp
# /python/pandas/pandas_exercises.asp
# /python/pandas/pandas_exercises.asp
# /python/pandas/pandas_quiz.asp
# /python/scipy/scipy_exercises.php
# /python/scipy/scipy_exercises.php
# /python/scipy/scipy_quiz.php
# /excel/excel_exercises.php
# /excel/excel_exercises.php
# /exercises/index.php
# /quiztest/default.asp
# https://campus.w3schools.com/collections/certifications/products/html-certificate
# https://campus.w3schools.com/collections/certifications/products/html-certificate
# https://campus.w3schools.com/collections/course-catalog/products/html-course
# https://campus.w3schools.com/collections/certifications/products/css-certificate
# https://campus.w3schools.com/collections/certifications/products/css-certificate
# https://campus.w3schools.com/collections/course-catalog/products/css-course
# https://campus.w3schools.com/collections/certifications/products/bootstrap-3-certificate
# https://campus.w3schools.com/collections/certifications/products/bootstrap-3-certificate
# https://campus.w3schools.com/collections/single-courses/products/bootstrap-course
# https://campus.w3schools.com/products/data-analytics-program
# https://campus.w3schools.com/products/data-analytics-program
# https://campus.w3schools.com/products/numpy-course
# https://campus.w3schools.com/products/numpy-course
# https://campus.w3schools.com/products/pandas-course
# https://campus.w3schools.com/products/pandas-course
# https://campus.w3schools.com/products/excel-certificate
# https://campus.w3schools.com/products/excel-certificate
# https://campus.w3schools.com/collections/course-best-sellers/products/social-media-marketing-course
# https://campus.w3schools.com/collections/course-best-sellers/products/social-media-marketing-course
# https://campus.w3schools.com
# https://campus.w3schools.com/collections/course-catalog/products/w3schools-full-access-course
# https://campus.w3schools.com/collections/certifications/products/front-end-course
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/course-catalog/products/front-end-course
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-modern-web-development
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/course-best-sellers/products/web-application-development-course
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-web-design
# https://campus.w3schools.com/collections/certifications/products/javascript-certificate
# https://campus.w3schools.com/collections/certifications/products/javascript-certificate
# https://campus.w3schools.com/collections/course-catalog/products/javascript-course
# https://campus.w3schools.com/collections/certifications/products/react-js-certificate
# https://campus.w3schools.com/collections/certifications/products/react-js-certificate
# https://campus.w3schools.com/collections/course-catalog/products/react-js-course
# https://campus.w3schools.com/collections/certifications/products/jquery-certificate
# https://campus.w3schools.com/collections/certifications/products/jquery-certificate
# https://campus.w3schools.com/collections/course-catalog/products/jquery-course
# https://campus.w3schools.com/products/vue-js-certification-exam
# https://campus.w3schools.com/products/vue-js-certification-exam
# https://campus.w3schools.com/collections/course-catalog/products/w3schools-full-access-course
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/course-catalog/products/front-end-course
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-modern-web-development
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/course-best-sellers/products/web-application-development-course
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-web-design
# https://campus.w3schools.com/collections/course-catalog/products/w3schools-full-access-course
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/course-catalog/products/front-end-course
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/certifications/products/modern-web-development-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-modern-web-development
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/certifications/products/web-application-development-certificates
# https://campus.w3schools.com/collections/course-best-sellers/products/web-application-development-course
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/certifications/products/web-design-certification
# https://campus.w3schools.com/collections/course-best-sellers/products/learn-web-design
# https://campus.w3schools.com/collections/certifications/products/python-certificate
# https://campus.w3schools.com/collections/certifications/products/python-certificate
# https://campus.w3schools.com/collections/course-catalog/products/python-course
# https://campus.w3schools.com/collections/certifications/products/sql-certificate
# https://campus.w3schools.com/collections/certifications/products/sql-certificate
# https://campus.w3schools.com/collections/course-catalog/products/sql-course
# https://campus.w3schools.com/collections/certifications/products/mysql-certificate
# https://campus.w3schools.com/collections/certifications/products/mysql-certificate
# https://campus.w3schools.com/collections/certifications/products/php-certificate
# https://campus.w3schools.com/collections/certifications/products/php-certificate
# https://campus.w3schools.com/collections/course-catalog/products/php-course
# https://campus.w3schools.com/collections/certifications/products/java-certificate
# https://campus.w3schools.com/collections/certifications/products/java-certificate
# https://campus.w3schools.com/collections/course-catalog/products/java-course
# https://campus.w3schools.com/collections/certifications/products/c-certificate
# https://campus.w3schools.com/collections/certifications/products/c-certificate
# https://campus.w3schools.com/collections/course-catalog/products/c-course-1
# https://campus.w3schools.com/collections/certifications/products/c-certificate-1
# https://campus.w3schools.com/collections/certifications/products/c-certificate-1
# https://campus.w3schools.com/collections/course-catalog/products/c-course
# https://campus.w3schools.com/collections/course-catalog/products/r-course
# https://campus.w3schools.com/collections/course-catalog/products/r-course
# https://campus.w3schools.com/products/django-certification-exam
# https://campus.w3schools.com/products/django-certification-exam
# https://campus.w3schools.com/collections/certifications/products/typescript-certificate
# https://campus.w3schools.com/collections/certifications/products/typescript-certificate
# https://campus.w3schools.com/products/learn-typescript
# https://campus.w3schools.com/collections/certifications/products/xml-certificate
# https://campus.w3schools.com/collections/certifications/products/xml-certificate
# https://campus.w3schools.com/collections/course-catalog/products/xml-course
# https://campus.w3schools.com/collections/certifications/products/cyber-security-certificate
# https://campus.w3schools.com/collections/certifications/products/cyber-security-certificate
# https://campus.w3schools.com/products/cyber-security-course
# https://campus.w3schools.com/collections/certifications/products/accessibility-certificate
# https://campus.w3schools.com/collections/certifications/products/accessibility-certificate
# https://campus.w3schools.com/products/accessibility-course
# https://campus.w3schools.com/collections/course-best-sellers/products/building-modern-python-apps-on-aws
# https://campus.w3schools.com/collections/course-best-sellers/products/building-modern-python-apps-on-aws
# /training/aws/home/
# /training/aws/home/
# https://campus.w3schools.com/products/data-analytics-program
# https://campus.w3schools.com/products/data-analytics-program
# https://campus.w3schools.com/products/numpy-course
# https://campus.w3schools.com/products/numpy-course
# https://campus.w3schools.com/products/pandas-course
# https://campus.w3schools.com/products/pandas-course
# https://campus.w3schools.com/products/excel-certificate
# https://campus.w3schools.com/products/excel-certificate
# https://campus.w3schools.com/collections/course-best-sellers/products/social-media-marketing-course
# https://campus.w3schools.com/collections/course-best-sellers/products/social-media-marketing-course
# https://campus.w3schools.com
# /tutorials/index.php
# /references/index.php
# /spaces/index.php
# /exercises/index.php
# /quiztest/default.asp
# https://campus.w3schools.com/collections/certifications
# /signup/index.php
# /signup/index.php
# /pro/index.php
# /where_to_start.asp
# /tryit/default.asp
# /w3css/w3css_templates.asp
# /howto/default.asp
# /videos/index.php
# /w3css/default.asp
# /spaces/index.php
# /spaces/index.php
# /browsers/default.asp
# /typingspeed/default.asp
# /training/aws/home/
# /colors/colors_picker.asp
# /codegame/index.html
# https://campus.w3schools.com/pages/newsletter
# https://www.facebook.com/w3schoolscom/
# https://www.instagram.com/w3schools.com_official/
# https://discord.gg/6Z7UaRbUQM
# https://www.linkedin.com/company/w3schools.com/
# javascript:void(0);
# /html/default.asp
# /css/default.asp
# /js/default.asp
# /sql/default.asp
# /python/default.asp
# /java/default.asp
# /php/default.asp
# /howto/default.asp
# /w3css/default.asp
# /c/index.php
# /cpp/default.asp
# /cs/index.php
# /bootstrap/bootstrap_ver.asp
# /react/default.asp
# /mysql/default.asp
# /jquery/default.asp
# /excel/index.php
# /xml/default.asp
# /django/index.php
# /nodejs/default.asp
# /r/default.asp
# /typescript/index.php
# /angular/default.asp
# /git/default.asp
# /postgresql/index.php
# /mongodb/index.php
# /asp/default.asp
# /aws/index.php
# /ai/default.asp
# /go/index.php
# /kotlin/index.php
# /sass/default.asp
# /vue/index.php
# /gen_ai/index.php
# /cybersecurity/index.php
# /datascience/default.asp
# javascript:void(0)
# default.asp
# sql_intro.asp
# sql_syntax.asp
# sql_select.asp
# sql_distinct.asp
# sql_where.asp
# sql_orderby.asp
# sql_and_or.asp
# sql_or.asp
# sql_not.asp
# sql_insert.asp
# sql_null_values.asp
# sql_update.asp
# sql_delete.asp
# sql_top.asp
# sql_min_max.asp
# sql_count.asp
# sql_sum.asp
# sql_avg.asp
# sql_like.asp
# sql_wildcards.asp
# sql_in.asp
# sql_between.asp
# sql_alias.asp
# sql_join.asp
# sql_join_inner.asp
# sql_join_left.asp
# sql_join_right.asp
# sql_join_full.asp
# sql_join_self.asp
# sql_union.asp
# sql_groupby.asp
# sql_having.asp
# sql_exists.asp
# sql_any_all.asp
# sql_select_into.asp
# sql_insert_into_select.asp
# sql_case.asp
# sql_isnull.asp
# sql_stored_procedures.asp
# sql_comments.asp
# sql_operators.asp
# sql_create_db.asp
# sql_drop_db.asp
# sql_backup_db.asp
# sql_create_table.asp
# sql_drop_table.asp
# sql_alter.asp
# sql_constraints.asp
# sql_notnull.asp
# sql_unique.asp
# sql_primarykey.asp
# sql_foreignkey.asp
# sql_check.asp
# sql_default.asp
# sql_create_index.asp
# sql_autoincrement.asp
# sql_dates.asp
# sql_view.asp
# sql_injection.asp
# sql_hosting.asp
# sql_datatypes.asp
# sql_ref_keywords.asp
# sql_ref_add.asp
# sql_ref_add_constraint.asp
# sql_ref_all.asp
# sql_ref_alter.asp
# sql_ref_alter_column.asp
# sql_ref_alter_table.asp
# sql_ref_and.asp
# sql_ref_any.asp
# sql_ref_as.asp
# sql_ref_asc.asp
# sql_ref_backup_database.asp
# sql_ref_between.asp
# sql_ref_case.asp
# sql_ref_check.asp
# sql_ref_column.asp
# sql_ref_constraint.asp
# sql_ref_create.asp
# sql_ref_create_database.asp
# sql_ref_create_index.asp
# sql_ref_create_or_replace_view.asp
# sql_ref_create_table.asp
# sql_ref_create_procedure.asp
# sql_ref_create_unique_index.asp
# sql_ref_create_view.asp
# sql_ref_database.asp
# sql_ref_default.asp
# sql_ref_delete.asp
# sql_ref_desc.asp
# sql_ref_distinct.asp
# sql_ref_drop.asp
# sql_ref_drop_column.asp
# sql_ref_drop_constraint.asp
# sql_ref_drop_database.asp
# sql_ref_drop_default.asp
# sql_ref_drop_index.asp
# sql_ref_drop_table.asp
# sql_ref_drop_view.asp
# sql_ref_exec.asp
# sql_ref_exists.asp
# sql_ref_foreign_key.asp
# sql_ref_from.asp
# sql_ref_full_outer_join.asp
# sql_ref_group_by.asp
# sql_ref_having.asp
# sql_ref_in.asp
# sql_ref_index.asp
# sql_ref_inner_join.asp
# sql_ref_insert_into.asp
# sql_ref_insert_into_select.asp
# sql_ref_is_null.asp
# sql_ref_is_not_null.asp
# sql_ref_join.asp
# sql_ref_left_join.asp
# sql_ref_like.asp
# sql_ref_limit.asp
# sql_ref_not.asp
# sql_ref_not_null.asp
# sql_ref_or.asp
# sql_ref_order_by.asp
# sql_ref_outer_join.asp
# sql_ref_primary_key.asp
# sql_ref_procedure.asp
# sql_ref_right_join.asp
# sql_ref_rownum.asp
# sql_ref_select.asp
# sql_ref_select_distinct.asp
# sql_ref_select_into.asp
# sql_ref_select_top.asp
# sql_ref_set.asp
# sql_ref_table.asp
# sql_ref_top.asp
# sql_ref_truncate_table.asp
# sql_ref_union.asp
# sql_ref_union_all.asp
# sql_ref_unique.asp
# sql_ref_update.asp
# sql_ref_values.asp
# sql_ref_view.asp
# sql_ref_where.asp
# sql_ref_mysql.asp
# func_mysql_ascii.asp
# func_mysql_char_length.asp
# func_mysql_character_length.asp
# func_mysql_concat.asp
# func_mysql_concat_ws.asp
# func_mysql_field.asp
# func_mysql_find_in_set.asp
# func_mysql_format.asp
# func_mysql_insert.asp
# func_mysql_instr.asp
# func_mysql_lcase.asp
# func_mysql_left.asp
# func_mysql_length.asp
# func_mysql_locate.asp
# func_mysql_lower.asp
# func_mysql_lpad.asp
# func_mysql_ltrim.asp
# func_mysql_mid.asp
# func_mysql_position.asp
# func_mysql_repeat.asp
# func_mysql_replace.asp
# func_mysql_reverse.asp
# func_mysql_right.asp
# func_mysql_rpad.asp
# func_mysql_rtrim.asp
# func_mysql_space.asp
# func_mysql_strcmp.asp
# func_mysql_substr.asp
# func_mysql_substring.asp
# func_mysql_substring_index.asp
# func_mysql_trim.asp
# func_mysql_ucase.asp
# func_mysql_upper.asp
# func_mysql_abs.asp
# func_mysql_acos.asp
# func_mysql_asin.asp
# func_mysql_atan.asp
# func_mysql_atan2.asp
# func_mysql_avg.asp
# func_mysql_ceil.asp
# func_mysql_ceiling.asp
# func_mysql_cos.asp
# func_mysql_cot.asp
# func_mysql_count.asp
# func_mysql_degrees.asp
# func_mysql_div.asp
# func_mysql_exp.asp
# func_mysql_floor.asp
# func_mysql_greatest.asp
# func_mysql_least.asp
# func_mysql_ln.asp
# func_mysql_log.asp
# func_mysql_log10.asp
# func_mysql_log2.asp
# func_mysql_max.asp
# func_mysql_min.asp
# func_mysql_mod.asp
# func_mysql_pi.asp
# func_mysql_pow.asp
# func_mysql_power.asp
# func_mysql_radians.asp
# func_mysql_rand.asp
# func_mysql_round.asp
# func_mysql_sign.asp
# func_mysql_sin.asp
# func_mysql_sqrt.asp
# func_mysql_sum.asp
# func_mysql_tan.asp
# func_mysql_truncate.asp
# func_mysql_adddate.asp
# func_mysql_addtime.asp
# func_mysql_curdate.asp
# func_mysql_current_date.asp
# func_mysql_current_time.asp
# func_mysql_current_timestamp.asp
# func_mysql_curtime.asp
# func_mysql_date.asp
# func_mysql_datediff.asp
# func_mysql_date_add.asp
# func_mysql_date_format.asp
# func_mysql_date_sub.asp
# func_mysql_day.asp
# func_mysql_dayname.asp
# func_mysql_dayofmonth.asp
# func_mysql_dayofweek.asp
# func_mysql_dayofyear.asp
# func_mysql_extract.asp
# func_mysql_from_days.asp
# func_mysql_hour.asp
# func_mysql_last_day.asp
# func_mysql_localtime.asp
# func_mysql_localtimestamp.asp
# func_mysql_makedate.asp
# func_mysql_maketime.asp
# func_mysql_microsecond.asp
# func_mysql_minute.asp
# func_mysql_month.asp
# func_mysql_monthname.asp
# func_mysql_now.asp
# func_mysql_period_add.asp
# func_mysql_period_diff.asp
# func_mysql_quarter.asp
# func_mysql_second.asp
# func_mysql_sec_to_time.asp
# func_mysql_str_to_date.asp
# func_mysql_subdate.asp
# func_mysql_subtime.asp
# func_mysql_sysdate.asp
# func_mysql_time.asp
# func_mysql_time_format.asp
# func_mysql_time_to_sec.asp
# func_mysql_timediff.asp
# func_mysql_timestamp.asp
# func_mysql_to_days.asp
# func_mysql_week.asp
# func_mysql_weekday.asp
# func_mysql_weekofyear.asp
# func_mysql_year.asp
# func_mysql_yearweek.asp
# func_mysql_bin.asp
# func_mysql_binary.asp
# func_mysql_case.asp
# func_mysql_cast.asp
# func_mysql_coalesce.asp
# func_mysql_connection_id.asp
# func_mysql_conv.asp
# func_mysql_convert.asp
# func_mysql_current_user.asp
# func_mysql_database.asp
# func_mysql_if.asp
# func_mysql_ifnull.asp
# func_mysql_isnull.asp
# func_mysql_last_insert_id.asp
# func_mysql_nullif.asp
# func_mysql_session_user.asp
# func_mysql_system_user.asp
# func_mysql_user.asp
# func_mysql_version.asp
# sql_ref_sqlserver.asp
# func_sqlserver_ascii.asp
# func_sqlserver_char.asp
# func_sqlserver_charindex.asp
# func_sqlserver_concat.asp
# func_sqlserver_concat_with_plus.asp
# func_sqlserver_concat_ws.asp
# func_sqlserver_datalength.asp
# func_sqlserver_difference.asp
# func_sqlserver_format.asp
# func_sqlserver_left.asp
# func_sqlserver_len.asp
# func_sqlserver_lower.asp
# func_sqlserver_ltrim.asp
# func_sqlserver_nchar.asp
# func_sqlserver_patindex.asp
# func_sqlserver_quotename.asp
# func_sqlserver_replace.asp
# func_sqlserver_replicate.asp
# func_sqlserver_reverse.asp
# func_sqlserver_right.asp
# func_sqlserver_rtrim.asp
# func_sqlserver_soundex.asp
# func_sqlserver_space.asp
# func_sqlserver_str.asp
# func_sqlserver_stuff.asp
# func_sqlserver_substring.asp
# func_sqlserver_translate.asp
# func_sqlserver_trim.asp
# func_sqlserver_unicode.asp
# func_sqlserver_upper.asp
# func_sqlserver_abs.asp
# func_sqlserver_acos.asp
# func_sqlserver_asin.asp
# func_sqlserver_atan.asp
# func_sqlserver_atn2.asp
# func_sqlserver_avg.asp
# func_sqlserver_ceiling.asp
# func_sqlserver_count.asp
# func_sqlserver_cos.asp
# func_sqlserver_cot.asp
# func_sqlserver_degrees.asp
# func_sqlserver_exp.asp
# func_sqlserver_floor.asp
# func_sqlserver_log.asp
# func_sqlserver_log10.asp
# func_sqlserver_max.asp
# func_sqlserver_min.asp
# func_sqlserver_pi.asp
# func_sqlserver_power.asp
# func_sqlserver_radians.asp
# func_sqlserver_rand.asp
# func_sqlserver_round.asp
# func_sqlserver_sign.asp
# func_sqlserver_sin.asp
# func_sqlserver_sqrt.asp
# func_sqlserver_square.asp
# func_sqlserver_sum.asp
# func_sqlserver_tan.asp
# func_sqlserver_current_timestamp.asp
# func_sqlserver_dateadd.asp
# func_sqlserver_datediff.asp
# func_sqlserver_datefromparts.asp
# func_sqlserver_datename.asp
# func_sqlserver_datepart.asp
# func_sqlserver_day.asp
# func_sqlserver_getdate.asp
# func_sqlserver_getutcdate.asp
# func_sqlserver_isdate.asp
# func_sqlserver_month.asp
# func_sqlserver_sysdatetime.asp
# func_sqlserver_year.asp
# func_sqlserver_cast.asp
# func_sqlserver_coalesce.asp
# func_sqlserver_convert.asp
# func_sqlserver_current_user.asp
# func_sqlserver_iif.asp
# func_sqlserver_isnull.asp
# func_sqlserver_isnumeric.asp
# func_sqlserver_nullif.asp
# func_sqlserver_session_user.asp
# func_sqlserver_sessionproperty.asp
# func_sqlserver_system_user.asp
# func_sqlserver_user_name.asp
# sql_ref_msaccess.asp
# func_msaccess_asc.asp
# func_msaccess_chr.asp
# func_msaccess_concat.asp
# func_msaccess_curdir.asp
# func_msaccess_format.asp
# func_msaccess_instr.asp
# func_msaccess_instrrev.asp
# func_msaccess_lcase.asp
# func_msaccess_left.asp
# func_msaccess_len.asp
# func_msaccess_ltrim.asp
# func_msaccess_mid.asp
# func_msaccess_replace.asp
# func_msaccess_right.asp
# func_msaccess_rtrim.asp
# func_msaccess_space.asp
# func_msaccess_split.asp
# func_msaccess_str.asp
# func_msaccess_strcomp.asp
# func_msaccess_strconv.asp
# func_msaccess_strreverse.asp
# func_msaccess_trim.asp
# func_msaccess_ucase.asp
# func_msaccess_abs.asp
# func_msaccess_atn.asp
# func_msaccess_avg.asp
# func_msaccess_cos.asp
# func_msaccess_count.asp
# func_msaccess_exp.asp
# func_msaccess_fix.asp
# func_msaccess_format_number.asp
# func_msaccess_int.asp
# func_msaccess_max.asp
# func_msaccess_min.asp
# func_msaccess_randomize.asp
# func_msaccess_rnd.asp
# func_msaccess_round.asp
# func_msaccess_sgn.asp
# func_msaccess_sqr.asp
# func_msaccess_sum.asp
# func_msaccess_val.asp
# func_msaccess_date.asp
# func_msaccess_dateadd.asp
# func_msaccess_datediff.asp
# func_msaccess_datepart.asp
# func_msaccess_dateserial.asp
# func_msaccess_datevalue.asp
# func_msaccess_day.asp
# func_msaccess_format_date.asp
# func_msaccess_hour.asp
# func_msaccess_minute.asp
# func_msaccess_month.asp
# func_msaccess_monthname.asp
# func_msaccess_now.asp
# func_msaccess_second.asp
# func_msaccess_time.asp
# func_msaccess_timeserial.asp
# func_msaccess_timevalue.asp
# func_msaccess_weekday.asp
# func_msaccess_weekdayname.asp
# func_msaccess_year.asp
# func_msaccess_currentuser.asp
# func_msaccess_environ.asp
# func_msaccess_isdate.asp
# func_msaccess_isnull.asp
# func_msaccess_isnumeric.asp
# sql_quickref.asp
# sql_examples.asp
# sql_editor.asp
# sql_quiz.asp
# sql_exercises.asp
# sql_bootcamp.asp
# sql_exam.asp
# /default.asp
# sql_intro.asp
# sql_intro.asp
# trysql.asp?filename=trysql_select_all
# exercise.asp?filename=exercise_select1
# sql_examples.asp
# sql_quiz.asp
# https://my-learning.w3schools.com/
# sql_ref_keywords.asp
# sql_ref_mysql.asp
# sql_ref_sqlserver.asp
# sql_ref_msaccess.asp
# sql_quickref.asp
# sql_datatypes.asp
# https://campus.w3schools.com/collections/course-catalog
# /default.asp
# sql_intro.asp
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# https://campus.w3schools.com/collections/course-catalog/products/w3schools-full-access-course
# /colors/colors_picker.asp
# /colors/colors_picker.asp
# https://www.facebook.com/w3schoolscom/
# https://www.instagram.com/w3schools.com_official/
# https://www.linkedin.com/company/w3schools.com/
# https://discord.gg/6Z7UaRbUQM
# https://campus.w3schools.com/collections/course-catalog/products/w3schools-full-access-course
# //www.w3schools.com
# /spaces/index.php
# /pro/index.php
# https://campus.w3schools.com/pages/newsletter
# https://campus.w3schools.com/collections/certifications
# javascript:void(0);
# /html/default.asp
# /css/default.asp
# /js/default.asp
# /howto/default.asp
# /sql/default.asp
# /python/default.asp
# /w3css/default.asp
# /bootstrap/bootstrap_ver.asp
# /php/default.asp
# /java/default.asp
# /cpp/default.asp
# /jquery/default.asp
# /tags/default.asp
# /cssref/index.php
# /jsref/default.asp
# /sql/sql_ref_keywords.asp
# /python/python_reference.asp
# /w3css/w3css_references.asp
# /bootstrap/bootstrap_ref_all_classes.asp
# /php/php_ref_overview.asp
# /colors/colors_names.asp
# /java/java_ref_keywords.asp
# /angular/angular_ref_directives.asp
# /jquery/jquery_ref_overview.asp
# /html/html_examples.asp
# /css/css_examples.asp
# /js/js_examples.asp
# /howto/default.asp
# /sql/sql_examples.asp
# /python/python_examples.asp
# /w3css/w3css_examples.asp
# /bootstrap/bootstrap_examples.asp
# /php/php_examples.asp
# /java/java_examples.asp
# /xml/xml_examples.asp
# /jquery/jquery_examples.asp
# https://campus.w3schools.com/collections/course-catalog
# https://campus.w3schools.com/collections/certifications/products/html-certificate
# https://campus.w3schools.com/collections/certifications/products/css-certificate
# https://campus.w3schools.com/collections/certifications/products/javascript-certificate
# https://campus.w3schools.com/collections/certifications/products/front-end-certificate
# https://campus.w3schools.com/collections/certifications/products/sql-certificate
# https://campus.w3schools.com/collections/certifications/products/python-certificate
# https://campus.w3schools.com/collections/certifications/products/php-certificate
# https://campus.w3schools.com/collections/certifications/products/jquery-certificate
# https://campus.w3schools.com/collections/certifications/products/java-certificate
# https://campus.w3schools.com/collections/certifications/products/c-certificate
# https://campus.w3schools.com/collections/certifications/products/c-certificate-1
# https://campus.w3schools.com/collections/certifications/products/xml-certificate
# https://www.facebook.com/w3schoolscom/
# https://discord.gg/6Z7UaRbUQM
# https://www.linkedin.com/company/w3schools.com/
# https://www.instagram.com/w3schools.com_official/
# /forum/default.asp
# /about/default.asp
# /about/about_copyright.asp
# /about/about_privacy.asp
# /about/about_copyright.asp
# //www.w3schools.com/w3css/default.asp
#
# The URL https://yournewsreporter.com/advantages-of-buying-authentic-basketball-jerseys/ returned an error: 404
#
# The URL https://yournewsreporter.com/4-tips-for-selecting-the-best-real-estate-agent/ returned an error: 404
